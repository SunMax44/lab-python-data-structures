# %% [markdown]
# # Lab | Data Structures

# %% [markdown]
# ## Exercise: Managing Customer Orders
#
# As part of a business venture, you are starting an online store that sells various products. To ensure smooth operations, you need to develop a program that manages customer orders and inventory.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a list called `products` that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".
#
# 2. Create an empty dictionary called `inventory`.
#
# 3. Ask the user to input the quantity of each product available in the inventory. Use the product names from the `products` list as keys in the `inventory` dictionary and assign the respective quantities as values.
#
# 4. Create an empty set called `customer_orders`.
#
# 5. Ask the user to input the name of three products that a customer wants to order (from those in the products list, meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". Add each product name to the `customer_orders` set.
#
# 6. Print the products in the `customer_orders` set.
#
# 7. Calculate the following order statistics:
#    - Total Products Ordered: The total number of products in the `customer_orders` set.
#    - Percentage of Products Ordered: The percentage of products ordered compared to the total available products.
#
#    Store these statistics in a tuple called `order_status`.
#
# 8. Print the order statistics using the following format:
#    ```
#    Order Statistics:
#    Total Products Ordered: <total_products_ordered>
#    Percentage of Products Ordered: <percentage_ordered>%
#    ```
#
# 9. Update the inventory by subtracting 1 from the quantity of each product. Modify the `inventory` dictionary accordingly.
#
# 10. Print the updated inventory, displaying the quantity of each product on separate lines.
#
# Solve the exercise by implementing the steps using the Python concepts of lists, dictionaries, sets, and basic input/output operations.

# %%
products = ["t-shirt", "mug", "hat", "book", "keychain"]
inventory = {}
for i in range(0,len(products)):
    inventory[products[i]] = input(f"Enter the quantity of {products[i]} in the inventory")
# Out:
# Enter the quantity of t-shirt in the inventory 5
# Enter the quantity of mug in the inventory 5
# Enter the quantity of hat in the inventory 5
# Enter the quantity of book in the inventory 5
# Enter the quantity of keychain in the inventory 5

# %%
customer_orders = set()
for i in range(0,3):
    order = input(f"Today, we sell {products[0]}s, {products[1]}s, {products[2]}s, {products[3]}s, {products[4]}s, choose three products, now type in the first one!")
    while order.strip("s") not in products:
        order = input(f"We only sell {products[0]}s, {products[1]}s, {products[2]}s, {products[3]}s, {products[4]}s, now type in the first one!")
    customer_orders.add(order.strip("s"))
print(customer_orders)
# Out:
# Today, we sell t-shirts, mugs, hats, books, keychains, choose three products, now type in the first one! t-shirt
# Today, we sell t-shirts, mugs, hats, books, keychains, choose three products, now type in the first one! mug
# Today, we sell t-shirts, mugs, hats, books, keychains, choose three products, now type in the first one! hat
# {'mug', 't-shirt', 'hat'}

# %%
total_products_ordered = len(customer_orders)
total_products_in_stock = int(inventory['t-shirt']) + int(inventory['mug']) + int(inventory['hat']) + int(inventory['book']) + int(inventory['keychain'])
percentage_of_products_ordered = str(int(total_products_ordered / total_products_in_stock * 100)) + "%"

# %%
print("Order Statistics:") # quesrtion wie in einem print mit zeilenbrecher???
print(f"Total Products Ordered: {total_products_ordered}")
print(f"Percentage of Products Ordered: {percentage_of_products_ordered}")
# Out:
# Order Statistics:
# Total Products Ordered: 3
# Percentage of Products Ordered: 12%

# %%
tshirt = int(inventory["t-shirt"])
mug = int(inventory["mug"])
hat = int(inventory["hat"])
book = int(inventory['book'])
keychain = int(inventory['keychain'])

if "t-shirt" in customer_orders:
    inventory["t-shirt"] = tshirt - 1
if "mug" in customer_orders:
    inventory["mug"] = mug - 1
if "hat" in customer_orders:
    inventory["hat"] = hat - 1
if "book" in customer_orders:
    inventory["book"] = book - 1
if "keychain" in customer_orders:
    inventory["keychain"] = keychain - 1

print("Updated inventory")
print(f"T-Shirts: {inventory['t-shirt']}")
print(f"Mugs: {inventory['mug']}")
print(f"Hats: {inventory['hat']}")
print(f"Books: {inventory['book']}")
print(f"Keychains: {inventory['keychain']}")
# Out:
# Updated inventory
# T-Shirts: 4
# Mugs: 4
# Hats: 4
# Books: 5
# Keychains: 5
